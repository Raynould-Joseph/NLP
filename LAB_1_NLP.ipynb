# %% [markdown]
# <a href="https://colab.research.google.com/github/Raynould-Joseph/NLP/blob/main/LAB_1_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-12537356-ecab-4d9e-83e4-c23a744f5000" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12537356-ecab-4d9e-83e4-c23a744f5000">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AmazonBooks - Sheet1csv.csv to AmazonBooks - Sheet1csv.csv

# %%
import nltk

word_data = "To declare your intention to graduate for a certain term you must complete the online Intent to Graduate.  Students should go to MyUIC website and login.  Click on the “Student” tab then the “Declare Your Intent to Graduate” portlet and follow the instructions linked below Note the following:Your current program and degree information should appear.  If it is incorrect, or if you are currently attempting to apply to receive a degree that is not listed (receiving a master’s while in a doctoral program, for example), submit a graduate degree that is listed.  A text box will be provided in a later screen where you can type in any corrections or messages.  An example of a message would be:  I am applying for the MS in “x” even though I am continuing in the PhD program.If the program and degree information appears to be from a previous program for which you are no longer interested, follow the same procedures listed directly above.If you are working on two programs in a joint program, information for both should appear.  If not, provide the information in the text box that you are also seeking the missing degree/programIf you are working concurrently on two programs and are receiving only one for this term, provide that information in the text box. (Note: this is only for concurrent programs.  Students in officially approved joint degree programs must receive both degrees in the same termThe Intent to Graduate site also allows you to input a diploma mailing address.  Diplomas are typically mailed one or two months after the end of the term of graduation"
nltk_tokens = nltk.word_tokenize(word_data)
print (nltk_tokens)
# Out:
# ['To', 'declare', 'your', 'intention', 'to', 'graduate', 'for', 'a', 'certain', 'term', 'you', 'must', 'complete', 'the', 'online', 'Intent', 'to', 'Graduate', '.', 'Students', 'should', 'go', 'to', 'MyUIC', 'website', 'and', 'login', '.', 'Click', 'on', 'the', '“', 'Student', '”', 'tab', 'then', 'the', '“', 'Declare', 'Your', 'Intent', 'to', 'Graduate', '”', 'portlet', 'and', 'follow', 'the', 'instructions', 'linked', 'below', 'Note', 'the', 'following', ':', 'Your', 'current', 'program', 'and', 'degree', 'information', 'should', 'appear', '.', 'If', 'it', 'is', 'incorrect', ',', 'or', 'if', 'you', 'are', 'currently', 'attempting', 'to', 'apply', 'to', 'receive', 'a', 'degree', 'that', 'is', 'not', 'listed', '(', 'receiving', 'a', 'master', '’', 's', 'while', 'in', 'a', 'doctoral', 'program', ',', 'for', 'example', ')', ',', 'submit', 'a', 'graduate', 'degree', 'that', 'is', 'listed', '.', 'A', 'text', 'box', 'will', 'be', 'provided', 'in', 'a', 'later', 'screen', 'where', 'you', 'c
# ...

# %%
# Python program to illustrate
# creating a data frame using CSV files
 
# import pandas module
import pandas as pd
import numpy as np
 
# creating a data frame
df = pd.read_csv("AmazonBooks - Sheet1csv.csv")
df = df.replace(np.nan, 0)
df.replace([np.inf, -np.inf], 0, inplace=True)

print(df.head)
# Out:
# <bound method NDFrame.head of                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 595  Live Free Or Die: America (and the World) on t...
# 596                                 Burn After Writing
# 597  Get Out of Your Head: Stopping the Spiral of T...
# 598  Human Body Activity Book for Kids: Hands-On Fu...
# 599                                 Educated: A Memoir
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
print (df)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 595  Live Free Or Die: America (and the World) on t...
# 596                                 Burn After Writing
# 597  Get Out of Your Head: Stopping the Spiral of T...
# 598  Human Body Activity Book for Kids: Hands-On Fu...
# 599                                 Educated: A Memoir
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
import nltk
nltk.download('punkt')
import nltk,csv,numpy 
from nltk import sent_tokenize, word_tokenize, pos_tag
reader = df.Name
for line in reader:
    for field in line:
        tokens = word_tokenize(field)
        print(tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Streaming output truncated to the last 5000 lines.
# ['o']
# ['t']
# ['a']
# ['l']
# []
# ['H']
# ['e']
# ['a']
# ['l']
# ['t']
# ['h']
# []
# ['a']
# ['n']
# ['d']
# []
# ['F']
# ['o']
# ['o']
# ['d']
# []
# ['F']
# ['r']
# ['e']
# ['e']
# ['d']
# ['o']
# ['m']
# ['T']
# ['h']
# ['e']
# []
# ['W']
# ['h']
# ['o']
# ['l']
# ['e']
# ['3']
# ['0']
# [':']
# []
# ['T']
# ['h']
# ['e']
# []
# ['3']
# ['0']
# ['-']
# ['D']
# ['a']
# ['y']
# []
# ['G']
# ['u']
# ['i']
# ['d']
# ['e']
# []
# ['t']
# ['o']
# []
# ['T']
# ['o']
# ['t']
# ['a']
# ['l']
# []
# ['H']
# ['e']
# ['a']
# ['l']
# ['t']
# ['h']
# []
# ['a']
# ['n']
# ['d']
# []
# ['F']
# ['o']
# ['o']
# ['d']
# []
# ['F']
# ['r']
# ['e']
# ['e']
# ['d']
# ['o']
# ['m']
# ['T']
# ['h']
# ['e']
# []
# ['W']
# ['h']
# ['o']
# ['l']
# ['e']
# ['3']
# ['0']
# [':']
# []
# ['T']
# ['h']
# ['e']
# []
# ['3']
# ['0']
# ['-']
# ...

# %%
reader = df.Name
a_dataframe = pd.DataFrame(reader)

numpy_array = a_dataframe.to_numpy()
np.savetxt("test_file.txt", numpy_array, fmt = "%s")

# %%
import nltk
nltk.download('punkt')
import nltk,csv,numpy 
from nltk import sent_tokenize, word_tokenize, pos_tag
reader = df.Author
print(reader)
nltk_tokens = nltk.sent_tokenize(reader)
print(nltk_tokens)
# Out:
# 0                      JJ Smith
# 1                  Stephen King
# 2            Jordan B. Peterson
# 3                 George Orwell
# 4      National Geographic Kids
#                  ...
# 595                Sean Hannity
# 596                Sharon Jones
# 597                Jennie Allen
# 598                Katie Stokes
# 599              Tara Westover
# Name: Author, Length: 600, dtype: object
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-df0fcb229e78> in <module>()
#       5 reader = df.Author
#       6 print(reader)
# ----> 7 nltk_tokens = nltk.sent_tokenize(reader)
#       8 print(nltk_tokens)
#
# /usr/local/lib/python3.7/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     105     """
# ...

# %%
import nltk
sentence_data = "To declare your intention to graduate for a certain term you must complete the online Intent to Graduate.  Students should go to MyUIC website and login.  Click on the “Student” tab then the “Declare Your Intent to Graduate” portlet and follow the instructions linked below Note the following:Your current program and degree information should appear.  If it is incorrect, or if you are currently attempting to apply to receive a degree that is not listed (receiving a master’s while in a doctoral program, for example), submit a graduate degree that is listed.  A text box will be provided in a later screen where you can type in any corrections or messages.  An example of a message would be:  I am applying for the MS in “x” even though I am continuing in the PhD program.If the program and degree information appears to be from a previous program for which you are no longer interested, follow the same procedures listed directly above.If you are working on two programs in a joint program, information for both should appear.  If not, provide the information in the text box that you are also seeking the missing degree/programIf you are working concurrently on two programs and are receiving only one for this term, provide that information in the text box. (Note: this is only for concurrent programs.  Students in officially approved joint degree programs must receive both degrees in the same termThe Intent to Graduate site also allows you to input a diploma mailing address.  Diplomas are typically mailed one or two months after the end of the term of graduation"
nltk_tokens = nltk.sent_tokenize(sentence_data)
print (nltk_tokens)
# Out:
# ['To declare your intention to graduate for a certain term you must complete the online Intent to Graduate.', 'Students should go to MyUIC website and login.', 'Click on the “Student” tab then the “Declare Your Intent to Graduate” portlet and follow the instructions linked below Note the following:Your current program and degree information should appear.', 'If it is incorrect, or if you are currently attempting to apply to receive a degree that is not listed (receiving a master’s while in a doctoral program, for example), submit a graduate degree that is listed.', 'A text box will be provided in a later screen where you can type in any corrections or messages.', 'An example of a message would be:  I am applying for the MS in “x” even though I am continuing in the PhD program.If the program and degree information appears to be from a previous program for which you are no longer interested, follow the same procedures listed directly above.If you are working on two programs in a joint 
# ...

# %%
import nltk,csv,numpy 
from nltk import sent_tokenize, word_tokenize, pos_tag
reader = csv.reader(open('AmazonBooks - Sheet1csv.csv', 'r'), delimiter= ",",quotechar='|')
print(reader)

# %%
import nltk
file_content = open("test_file.txt").read()
tokens = nltk.word_tokenize(file_content)
print (tokens)
# Out:
# ['10-Day', 'Green', 'Smoothie', 'Cleanse', '11/22/63', ':', 'A', 'Novel', '12', 'Rules', 'for', 'Life', ':', 'An', 'Antidote', 'to', 'Chaos', '1984', '(', 'Signet', 'Classics', ')', '5,000', 'Awesome', 'Facts', '(', 'About', 'Everything', '!', ')', '(', 'National', 'Geographic', 'Kids', ')', 'A', 'Dance', 'with', 'Dragons', '(', 'A', 'Song', 'of', 'Ice', 'and', 'Fire', ')', 'A', 'Game', 'of', 'Thrones', '/', 'A', 'Clash', 'of', 'Kings', '/', 'A', 'Storm', 'of', 'Swords', '/', 'A', 'Feast', 'of', 'Crows', '/', 'A', 'Dance', 'with', 'Dragons', 'A', 'Gentleman', 'in', 'Moscow', ':', 'A', 'Novel', 'A', 'Higher', 'Loyalty', ':', 'Truth', ',', 'Lies', ',', 'and', 'Leadership', 'A', 'Man', 'Called', 'Ove', ':', 'A', 'Novel', 'A', 'Man', 'Called', 'Ove', ':', 'A', 'Novel', 'A', 'Patriot', "'s", 'History', 'of', 'the', 'United', 'States', ':', 'From', 'Columbus', "'s", 'Great', 'Discovery', 'to', 'the', 'War', 'on', 'Terror', 'A', 'Stolen', 'Life', ':', 'A', 'Memoir', 'A', 'Wrinkle', 'in', 'T
# ...

# %%
import nltk
file_content = open("main.txt").read()
tokens = file_content .split(',')
print (tokens)
# Out:
# ["Author\nJJ Smith\nStephen King\nJordan B. Peterson\nGeorge Orwell\nNational Geographic Kids\nGeorge R. R. Martin\nGeorge R. R. Martin\nAmor Towles\nJames Comey\nFredrik Backman\nFredrik Backman\nLarry Schweikart\nJaycee Dugard\nMadeleine L'Engle\nSteve Harvey\nAdult Coloring Book Designs\nBlue Star Coloring\nBlue Star Coloring\nColoring Books for Adults\nRon Chernow\nAnthony Doerr\nAnthony Doerr\nVeronica Roth\nChris Kyle\nKhaled Hosseini\nGlenn Beck\nNeil deGrasse Tyson\nMark Twain\nDK\nAngie Grace\nIna Garten\nIna Garten\nMichelle Obama\nMichelle Obama\nAtul Gawande\nTa-Nehisi Coates\nTa-Nehisi Coates\nBruce Springsteen\nStephenie Meyer\nGlenn Beck\nBill Martin Jr.\nBill Martin Jr.\nJeff Kinney\nSasha O'Hara\nDavid Goggins\nThomas Piketty\nSuzanne Collins\nSuzanne Collins\nSuzanne Collins\nChrissy Teigen\nFrancis Chan\nFrancis Chan\nFrancis Chan\nKevin Kwan\nMarjorie Sarnat\nMarjorie Sarnat\nAbraham Verghese\nAbraham Verghese\nBreneÃŒÂ\x81 Brown\nMalcolm Gladwell\nCharlaine Harri
# ...

# %%
from nltk.tokenize import TreebankWordTokenizer
  
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(file_content)
# Out:
# ['Author',
#  'JJ',
#  'Smith',
#  'Stephen',
#  'King',
#  'Jordan',
#  'B.',
#  'Peterson',
#  'George',
#  'Orwell',
#  'National',
#  'Geographic',
#  'Kids',
#  'George',
#  'R.',
#  'R.',
#  'Martin',
#  'George',
#  'R.',
#  'R.',
#  'Martin',
#  'Amor',
#  'Towles',
#  'James',
#  'Comey',
#  'Fredrik',
#  'Backman',
#  'Fredrik',
#  'Backman',
#  'Larry',
#  'Schweikart',
#  'Jaycee',
#  'Dugard',
#  'Madeleine',
#  "L'Engle",
#  'Steve',
#  'Harvey',
#  'Adult',
#  'Coloring',
#  'Book',
#  'Designs',
#  'Blue',
#  'Star',
#  'Coloring',
#  'Blue',
#  'Star',
#  'Coloring',
#  'Coloring',
#  'Books',
#  'for',
#  'Adults',
#  'Ron',
#  'Chernow',
#  'Anthony',
#  'Doerr',
#  'Anthony',
#  'Doerr',
#  'Veronica',
#  'Roth',
#  'Chris',
#  'Kyle',
#  'Khaled',
#  'Hosseini',
#  'Glenn',
#  'Beck',
#  'Neil',
#  'deGrasse',
#  'Tyson',
#  'Mark',
#  'Twain',
#  'DK',
#  'Angie',
#  'Grace',
#  'Ina',
#  'Garten',
#  'Ina',
#  'Garten',
#  'Michelle',
#  'Obama',
# ...

# %%
from nltk.tokenize import WordPunctTokenizer
  
tokenizer = WordPunctTokenizer()
tokenizer.tokenize(file_content)
# Out:
# ['Author',
#  'JJ',
#  'Smith',
#  'Stephen',
#  'King',
#  'Jordan',
#  'B',
#  '.',
#  'Peterson',
#  'George',
#  'Orwell',
#  'National',
#  'Geographic',
#  'Kids',
#  'George',
#  'R',
#  '.',
#  'R',
#  '.',
#  'Martin',
#  'George',
#  'R',
#  '.',
#  'R',
#  '.',
#  'Martin',
#  'Amor',
#  'Towles',
#  'James',
#  'Comey',
#  'Fredrik',
#  'Backman',
#  'Fredrik',
#  'Backman',
#  'Larry',
#  'Schweikart',
#  'Jaycee',
#  'Dugard',
#  'Madeleine',
#  'L',
#  "'",
#  'Engle',
#  'Steve',
#  'Harvey',
#  'Adult',
#  'Coloring',
#  'Book',
#  'Designs',
#  'Blue',
#  'Star',
#  'Coloring',
#  'Blue',
#  'Star',
#  'Coloring',
#  'Coloring',
#  'Books',
#  'for',
#  'Adults',
#  'Ron',
#  'Chernow',
#  'Anthony',
#  'Doerr',
#  'Anthony',
#  'Doerr',
#  'Veronica',
#  'Roth',
#  'Chris',
#  'Kyle',
#  'Khaled',
#  'Hosseini',
#  'Glenn',
#  'Beck',
#  'Neil',
#  'deGrasse',
#  'Tyson',
#  'Mark',
#  'Twain',
#  'DK',
#  'Angie',
#  'Grace',
#  'Ina',
#  'Garten',
#  'Ina',
# ...

# %%
from nltk.tokenize import RegexpTokenizer
  
tokenizer = RegexpTokenizer("[\w']+")
tokenizer.tokenize(file_content)
# Out:
# ['Author',
#  'JJ',
#  'Smith',
#  'Stephen',
#  'King',
#  'Jordan',
#  'B',
#  'Peterson',
#  'George',
#  'Orwell',
#  'National',
#  'Geographic',
#  'Kids',
#  'George',
#  'R',
#  'R',
#  'Martin',
#  'George',
#  'R',
#  'R',
#  'Martin',
#  'Amor',
#  'Towles',
#  'James',
#  'Comey',
#  'Fredrik',
#  'Backman',
#  'Fredrik',
#  'Backman',
#  'Larry',
#  'Schweikart',
#  'Jaycee',
#  'Dugard',
#  'Madeleine',
#  "L'Engle",
#  'Steve',
#  'Harvey',
#  'Adult',
#  'Coloring',
#  'Book',
#  'Designs',
#  'Blue',
#  'Star',
#  'Coloring',
#  'Blue',
#  'Star',
#  'Coloring',
#  'Coloring',
#  'Books',
#  'for',
#  'Adults',
#  'Ron',
#  'Chernow',
#  'Anthony',
#  'Doerr',
#  'Anthony',
#  'Doerr',
#  'Veronica',
#  'Roth',
#  'Chris',
#  'Kyle',
#  'Khaled',
#  'Hosseini',
#  'Glenn',
#  'Beck',
#  'Neil',
#  'deGrasse',
#  'Tyson',
#  'Mark',
#  'Twain',
#  'DK',
#  'Angie',
#  'Grace',
#  'Ina',
#  'Garten',
#  'Ina',
#  'Garten',
#  'Michelle',
#  'Obama',
#  'Michelle',
# ...
