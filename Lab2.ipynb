# %% [markdown]
# <a href="https://colab.research.google.com/github/Raynould-Joseph/NLP/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fe3085c4-e284-4c44-bb0a-e44e0e6c53b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fe3085c4-e284-4c44-bb0a-e44e0e6c53b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-8884be70d23e> in <module>()
#       2
#       3
# ----> 4 uploaded = files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      39   """
#      40
# ---> 41   uploaded_files = _upload_files(multiple=True)
#      42   # Mapping from original filename to filename as saved locally.
#      43   local_filenames = dict()
#
# ...

# %%
# import pandas module
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/MyDrive/NLP lab/AmazonBooks - Sheet1csv.csv')
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 595  Live Free Or Die: America (and the World) on t...
# 596                                 Burn After Writing
# 597  Get Out of Your Head: Stopping the Spiral of T...
# 598  Human Body Activity Book for Kids: Hands-On Fu...
# 599                                 Educated: A Memoir
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# Python program to illustrate
# creating a data frame using CSV files
 
# import pandas module
import pandas as pd
import numpy as np
 
# creating a data frame
df = pd.read_csv("AmazonBooks - Sheet1csv.csv")
df = df.replace(np.nan, 0)
df.replace([np.inf, -np.inf], 0, inplace=True)

print(df.head)
# Out:
# <bound method NDFrame.head of                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 595  Live Free Or Die: America (and the World) on t...
# 596                                 Burn After Writing
# 597  Get Out of Your Head: Stopping the Spiral of T...
# 598  Human Body Activity Book for Kids: Hands-On Fu...
# 599                                 Educated: A Memoir
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
print(df.Genre)
# Out:
# 0      Non Fiction
# 1          Fiction
# 2      Non Fiction
# 3          Fiction
# 4      Non Fiction
#           ...
# 595    Non Fiction
# 596    Non Fiction
# 597    Non Fiction
# 598    Non Fiction
# 599    Non Fiction
# Name: Genre, Length: 600, dtype: object

# %%
reader = df.Genre
a_dataframe = pd.DataFrame(reader)

numpy_array = a_dataframe.to_numpy()
np.savetxt("genre.txt", numpy_array, fmt = "%s")

# %%
import nltk
nltk.download('punkt')
file_content = open("genre.txt").read()
tokens = nltk.word_tokenize(file_content)
print (tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...

# %%
import nltk
nltk.download('stopwords')
  
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist 


stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(file_content)

filtered_sentence_genre = [w for w in word_tokens if not w in stop_words]

filtered_sentence_genre = []

for w in word_tokens:
  if w not in stop_words:
    filtered_sentence_genre.append(w)
print(filtered_sentence_genre)


wordfreq_genre = []
for w in filtered_sentence_genre:
    wordfreq_genre.append(filtered_sentence_genre.count(w))

print(filtered_sentence_genre,wordfreq_genre)
# Out:
# ['JJ', 'Smith', 'Stephen', 'King', 'Jordan', 'B.', 'Peterson', 'George', 'Orwell', 'National', 'Geographic', 'Kids', 'George', 'R.', 'R.', 'Martin', 'George', 'R.', 'R.', 'Martin', 'Amor', 'Towles', 'James', 'Comey', 'Fredrik', 'Backman', 'Fredrik', 'Backman', 'Larry', 'Schweikart', 'Jaycee', 'Dugard', 'Madeleine', "L'Engle", 'Steve', 'Harvey', 'Adult', 'Coloring', 'Book', 'Designs', 'Blue', 'Star', 'Coloring', 'Blue', 'Star', 'Coloring', 'Coloring', 'Books', 'Adults', 'Ron', 'Chernow', 'Anthony', 'Doerr', 'Anthony', 'Doerr', 'Veronica', 'Roth', 'Chris', 'Kyle', 'Khaled', 'Hosseini', 'Glenn', 'Beck', 'Neil', 'deGrasse', 'Tyson', 'Mark', 'Twain', 'DK', 'Angie', 'Grace', 'Ina', 'Garten', 'Ina', 'Garten', 'Michelle', 'Obama', 'Michelle', 'Obama', 'Atul', 'Gawande', 'Ta-Nehisi', 'Coates', 'Ta-Nehisi', 'Coates', 'Bruce', 'Springsteen', 'Stephenie', 'Meyer', 'Glenn', 'Beck', 'Bill', 'Martin', 'Jr.', 'Bill', 'Martin', 'Jr.', 'Jeff', 'Kinney', 'Sasha', "O'Hara", 'David', 'Goggins', 'Thomas',
# ...

# %%
print(wordfreq)
# Out:
# [337, 600, 600, 337, 600, 600, 337, 600, 600, 600, 600, 337, 600, 600, 600, 337, 600, 337, 600, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 600, 600, 600, 337, 600, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 600, 337, 600, 600, 600, 600, 337, 600, 337, 600, 337, 600, 600, 600, 600, 337, 600, 337, 600, 337, 600, 337, 600, 600, 337, 600, 337, 600, 600, 600, 337, 600, 337, 600, 600, 600, 600, 600, 600, 600, 600, 337, 600, 337, 600, 337, 600, 337, 600, 600, 600, 600, 337, 600, 600, 600, 600, 337, 600, 600, 600, 600, 600, 600, 600, 600, 600, 600, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 600, 600, 337, 600, 337, 600, 337, 600, 600, 600, 600, 337, 600, 600, 600, 600, 600, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 337, 600, 600, 337, 600, 600, 600, 600, 337, 600, 337, 600, 600, 600, 600, 600, 600, 337, 600, 337, 600, 337, 600, 337, 60
# ...

# %%
import matplotlib.pyplot as plt
plt.bar(filtered_sentence_genre,wordfreq_genre,30,30)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 141 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib.pyplot as plt

x=filtered_sentence
y=wordfreq
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title("A simple line graph")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 141 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
print(df.Author)
# Out:
# 0                      JJ Smith
# 1                  Stephen King
# 2            Jordan B. Peterson
# 3                 George Orwell
# 4      National Geographic Kids
#                  ...
# 595                Sean Hannity
# 596                Sharon Jones
# 597                Jennie Allen
# 598                Katie Stokes
# 599              Tara Westover
# Name: Author, Length: 600, dtype: object

# %%
reader = df.Author
a_dataframe = pd.DataFrame(reader)

numpy_array = a_dataframe.to_numpy()
np.savetxt("author.txt", numpy_array, fmt = "%s")

# %%
import nltk
nltk.download('punkt')
file_content = open("genre.txt").read()
tokens = nltk.word_tokenize(file_content)
print (tokens)
# Out:
# ['JJ', 'Smith', 'Stephen', 'King', 'Jordan', 'B.', 'Peterson', 'George', 'Orwell', 'National', 'Geographic', 'Kids', 'George', 'R.', 'R.', 'Martin', 'George', 'R.', 'R.', 'Martin', 'Amor', 'Towles', 'James', 'Comey', 'Fredrik', 'Backman', 'Fredrik', 'Backman', 'Larry', 'Schweikart', 'Jaycee', 'Dugard', 'Madeleine', "L'Engle", 'Steve', 'Harvey', 'Adult', 'Coloring', 'Book', 'Designs', 'Blue', 'Star', 'Coloring', 'Blue', 'Star', 'Coloring', 'Coloring', 'Books', 'for', 'Adults', 'Ron', 'Chernow', 'Anthony', 'Doerr', 'Anthony', 'Doerr', 'Veronica', 'Roth', 'Chris', 'Kyle', 'Khaled', 'Hosseini', 'Glenn', 'Beck', 'Neil', 'deGrasse', 'Tyson', 'Mark', 'Twain', 'DK', 'Angie', 'Grace', 'Ina', 'Garten', 'Ina', 'Garten', 'Michelle', 'Obama', 'Michelle', 'Obama', 'Atul', 'Gawande', 'Ta-Nehisi', 'Coates', 'Ta-Nehisi', 'Coates', 'Bruce', 'Springsteen', 'Stephenie', 'Meyer', 'Glenn', 'Beck', 'Bill', 'Martin', 'Jr.', 'Bill', 'Martin', 'Jr.', 'Jeff', 'Kinney', 'Sasha', "O'Hara", 'David', 'Goggins', 'T
# ...

# %%
import nltk
nltk.download('stopwords')
  
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist 


stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(file_content)

filtered_sentence = [w for w in word_tokens if not w in stop_words]

filtered_sentence = []

for w in word_tokens:
  if w not in stop_words:
    filtered_sentence.append(w)
print(filtered_sentence)


wordfreq = []
for w in filtered_sentence:
    wordfreq.append(filtered_sentence.count(w))

print(filtered_sentence,wordfreq)
# Out:
# ['JJ', 'Smith', 'Stephen', 'King', 'Jordan', 'B.', 'Peterson', 'George', 'Orwell', 'National', 'Geographic', 'Kids', 'George', 'R.', 'R.', 'Martin', 'George', 'R.', 'R.', 'Martin', 'Amor', 'Towles', 'James', 'Comey', 'Fredrik', 'Backman', 'Fredrik', 'Backman', 'Larry', 'Schweikart', 'Jaycee', 'Dugard', 'Madeleine', "L'Engle", 'Steve', 'Harvey', 'Adult', 'Coloring', 'Book', 'Designs', 'Blue', 'Star', 'Coloring', 'Blue', 'Star', 'Coloring', 'Coloring', 'Books', 'Adults', 'Ron', 'Chernow', 'Anthony', 'Doerr', 'Anthony', 'Doerr', 'Veronica', 'Roth', 'Chris', 'Kyle', 'Khaled', 'Hosseini', 'Glenn', 'Beck', 'Neil', 'deGrasse', 'Tyson', 'Mark', 'Twain', 'DK', 'Angie', 'Grace', 'Ina', 'Garten', 'Ina', 'Garten', 'Michelle', 'Obama', 'Michelle', 'Obama', 'Atul', 'Gawande', 'Ta-Nehisi', 'Coates', 'Ta-Nehisi', 'Coates', 'Bruce', 'Springsteen', 'Stephenie', 'Meyer', 'Glenn', 'Beck', 'Bill', 'Martin', 'Jr.', 'Bill', 'Martin', 'Jr.', 'Jeff', 'Kinney', 'Sasha', "O'Hara", 'David', 'Goggins', 'Thomas',
# ...

# %%
import matplotlib.pyplot as plt

x=filtered_sentence
y=wordfreq
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title("A simple line graph")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 141 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from matplotlib import pyplot as plt    
from matplotlib import pyplot as plt    
percentage = filtered_sentence_genre
number_of_student =  wordfreq_genre  
plt.hist(percentage, number_of_student, histtype='bar', rwidth=0.8)    
plt.xlabel('percentage')    
plt.ylabel('Number of people')    
plt.title('Histogram')    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-b747a6c0cacb> in <module>()
#       4
#       5 number_of_student =  wordfreq_genre
# ----> 6 plt.hist(percentage, number_of_student, histtype='bar', rwidth=0.8)
#       7 plt.xlabel('percentage')
#       8 plt.ylabel('Number of people')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt
fig =plt.figure()
myaxes=fig.add_axes([0.1,0.1,1.6,1.6])
myaxes.plot(filtered_sentence_genre,wordfreq_genre,'r',lw=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 141 missing from current font.
#   font.set_text(s, 0, flags=flags)
